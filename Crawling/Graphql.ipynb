# %%
import requests
import math
from time import sleep
import numpy as np
import pandas as pd

# %%
headers = {
    'referer': 'https://pcmap.place.naver.com/place/11657766/review/visitor?reviewItem=0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.41 Safari/537.36'
}

# %%
review_data = pd.DataFrame(data=[], columns=['별점','리뷰'])

total_item_no = None

now_loop_count = 0
total_loop_count = 10000
total_item = 0

while True:
    if total_loop_count<=now_loop_count:
        break
    data = dict(
    operationName= "getVisitorReviews",
    query="query getVisitorReviews($input: VisitorReviewsInput) {\n  visitorReviews(input: $input) {\n    items {\n      id\n      rating\n      author {\n        id\n        nickname\n        from\n        imageUrl\n        objectId\n        url\n        review {\n          totalCount\n          imageCount\n          avgRating\n          __typename\n        }\n        theme {\n          totalCount\n          __typename\n        }\n        __typename\n      }\n      body\n      thumbnail\n      media {\n        type\n        thumbnail\n        class\n        __typename\n      }\n      tags\n      status\n      visitCount\n      viewCount\n      visited\n      created\n      reply {\n        editUrl\n        body\n        editedBy\n        created\n        replyTitle\n        __typename\n      }\n      originType\n      item {\n        name\n        code\n        options\n        __typename\n      }\n      language\n      highlightOffsets\n      apolloCacheId\n      translatedText\n      businessName\n      showBookingItemName\n      showBookingItemOptions\n      bookingItemName\n      bookingItemOptions\n      votedKeywords {\n        code\n        iconUrl\n        iconCode\n        displayName\n        __typename\n      }\n      userIdno\n      isFollowing\n      followerCount\n      followRequested\n      loginIdno\n      __typename\n    }\n    starDistribution {\n      score\n      count\n      __typename\n    }\n    hideProductSelectBox\n    total\n    showRecommendationSort\n    __typename\n  }\n}\n",
    variables=dict(
        id="11657766",
        input={
            "bookingBusinessId": "null",
            "businessId": "11657766",
            "businessType": "place",
            "cidList": ["222117", "222121", "222160", "232110"],
            "display": 30,
            "getAuthorInfo": True,
            "includeContent": True,
            "includeReceiptPhotos": True,
            "isPhotoUsed": False,
            "item": "0",
            "page": now_loop_count+1
            }
        )
    )
    resp = requests.post('https://pcmap-api.place.naver.com/place/graphql',
                     headers=headers,
                     json=data)
    data = resp.json()
    
    total_item = data['data']['visitorReviews']['total']
    if total_item_no is None and total_item:
        # 첫 시작 & 요청 제대로
        total_item_no = total_item
        total_loop_count = math.ceil(total_item_no/30)
        now_loop_count+=1
        
        print("첫시작 응답 잘 옴")
        print("total개수;", total_item_no)
        
    elif total_item_no is None and not total_item:
        # 요청 제대로 안 옴 & 첫 시작 
        print(" 요청 제대로 안 옴 & 첫 시작  => 기다림")
        sleep(3)
        continue
        
        
    elif not total_item and not total_item_no:
        # 첫 시작 X & 응답 안줌 => 기다림
        sleep(3)
        print("첫 시작 X & 응답 안줌 => 기다림")
        continue
        
    elif total_item_no and total_item:
        # 첫 시작 X  & 응답도 잘 옴
        now_loop_count+=1
        sleep(1)
        print("응답 잘 옴 ")
    else:
        print("첫 시작 X & 응답 안줌")
        print("total item: ", total_item, "\n total_item_no:", total_item_no)
        sleep(3)
        continue
    
    
        
        
        
    items = data['data']['visitorReviews']['items']
    print("{}페이지 items개수 {}".format(now_loop_count, len(items)))
    for item in items:
        tmp = []
        tmp.append(str(item['rating']) + " " + str(item['created']))
        tmp.append(item['body'])
        tmp = pd.DataFrame(data=[tmp], columns=review_data.columns)
        review_data = pd.concat([review_data,tmp])
        
#         review.append(item['body', 'rating', 'created'])
# data = pd.DataFrame(data=[], columns=['별점','리뷰'])
# tmp =[]
#         tmp.append(rating)
#         tmp.append(review_content)
#         tmp = pd.DataFrame(data=[tmp], columns=data.columns)
#         data = pd.concat([data,tmp])
# Out:
# 첫시작 응답 잘 옴
# total개수; 4093
# 1페이지 items개수 30
# 응답 잘 옴
# 2페이지 items개수 30
# 응답 잘 옴
# 3페이지 items개수 30
# 응답 잘 옴
# 4페이지 items개수 30
# 응답 잘 옴
# 5페이지 items개수 30
# 응답 잘 옴
# 6페이지 items개수 30
# 응답 잘 옴
# 7페이지 items개수 30
# 응답 잘 옴
# 8페이지 items개수 30
# 응답 잘 옴
# 9페이지 items개수 30
# 응답 잘 옴
# 10페이지 items개수 30
# 응답 잘 옴
# 11페이지 items개수 30
# 응답 잘 옴
# 12페이지 items개수 30
# 응답 잘 옴
# 13페이지 items개수 30
# 응답 잘 옴
# 14페이지 items개수 30
# 응답 잘 옴
# 15페이지 items개수 30
# 응답 잘 옴
# 16페이지 items개수 30
# 응답 잘 옴
# 17페이지 items개수 30
# 응답 잘 옴
# 18페이지 items개수 30
# 응답 잘 옴
# 19페이지 items개수 30
# 응답 잘 옴
# 20페이지 items개수 30
# 응답 잘 옴
# 21페이지 items개수 30
# 응답 잘 옴
# 22페이지 items개수 30
# 응답 잘 옴
# 23페이지 items개수 30
# 응답 잘 옴
# 24페이지 items개수 30
# 응답 잘 옴
# 25페이지 items개수 30
# 응답 잘 옴
# 26페이지 items개수 30
# 응답 잘 옴
# 27페이지 items개수 30
# 응답 잘 옴
# 28페이지 items개수 30
# 응답 잘 옴
# 29페이지 items개수 30
# 응답 잘 옴
# 30페이지 items개수 30
# 응답 잘 옴
# 31페이지 items개수 30
# 응답 잘 옴
# 32페이지 items개수 30
# 응답 잘 옴
# 33페이지 items개수 30
# 응답 잘 옴
# 34페이지 items개수 30
# 응답 잘 옴
# 35페이지 items개수 30
# 응답 잘 옴
# 36페이지 items개수 30
# 응답 잘 옴
# 37페이지 items개수 30
# 응답 잘 옴
# 38페이지 items개수 30
# 응답 잘 옴
# 39페이지 items개수 30
# 응답 잘 옴
# 40페이지 items개수 30
# 응답 잘 옴
# 41페이지 items개수 30
# 응답 잘 옴
# 42페이지 items개수 30
# 응답 잘 옴
# 43페이지 items개수 30
# 응답 잘 옴
# 44페이지 items개수 30
# 응답 잘 옴
# 45페이지 items개수 30
# 응답 잘 옴
# 46페이지 items개수 30
# 응답 잘 옴
# 47페이지 items개수 30
# 응답 잘 옴
# 48페이지 items개수 30
# 응답 잘 옴
# 49페이지 items개수 30
# 응답 잘 옴
# 50페이지 items개수 30
# 응답 잘 옴
# 51페이지 items개수 30
# 응답 잘 옴
# 52페이지 items개수 30
# 응답 잘 옴
# 53페이지 items개수 30
# 응답 잘 옴
# 54페이지 items개수 30
# 응답 잘 옴
# 55페이지 items개수 30
# 응답 잘 옴
# 56페이지 items개수 30
# 응답 잘 옴
# 57페이지 items개수 30
# 응답 잘 옴
# 58페이지 items개수 30
# 응답 잘 옴
# 59페이지 items개수 30
# 응답 잘 옴
# 60페이지 items개수 30
# 응답 잘 옴
# 61페이지 items개수 30
# 응답 잘 옴
# 62페이지 items개수 30
# 응답 잘 옴
# 63페이지 items개수 30
# 응답 잘 옴
# 64페이지 items개수 30
# 응답 잘 옴
# 65페이지 items개수 30
# 응답 잘 옴
# 66페이지 items개수 30
# 응답 잘 옴
# 67페이지 items개수 30
# 응답 잘 옴
# 68페이지 items개수 30
# 응답 잘 옴
# 69페이지 items개수 30
# 응답 잘 옴
# 70페이지 items개수 30
# 응답 잘 옴
# 71페이지 items개수 30
# 응답 잘 옴
# 72페이지 items개수 30
# 응답 잘 옴
# 73페이지 items개수 30
# 응답 잘 옴
# 74페이지 items개수 30
# 응답 잘 옴
# 75페이지 items개수 30
# 응답 잘 옴
# 76페이지 items개수 30
# 응답 잘 옴
# 77페이지 items개수 30
# 응답 잘 옴
# 78페이지 items개수 30
# 응답 잘 옴
# 79페이지 items개수 30
# 응답 잘 옴
# 80페이지 items개수 30
# 응답 잘 옴
# 81페이지 items개수 30
# 응답 잘 옴
# 82페이지 items개수 30
# 응답 잘 옴
# 83페이지 items개수 30
# 응답 잘 옴
# 84페이지 items개수 30
# 응답 잘 옴
# 85페이지 items개수 30
# 응답 잘 옴
# 86페이지 items개수 30
# 응답 잘 옴
# 87페이지 items개수 30
# 응답 잘 옴
# 88페이지 items개수 30
# 응답 잘 옴
# 89페이지 items개수 30
# 응답 잘 옴
# 90페이지 items개수 30
# 응답 잘 옴
# 91페이지 items개수 30
# 응답 잘 옴
# 92페이지 items개수 30
# 응답 잘 옴
# 93페이지 items개수 30
# 응답 잘 옴
# 94페이지 items개수 30
# 응답 잘 옴
# 95페이지 items개수 30
# 응답 잘 옴
# 96페이지 items개수 30
# 응답 잘 옴
# 97페이지 items개수 30
# 응답 잘 옴
# 98페이지 items개수 30
# 응답 잘 옴
# 99페이지 items개수 30
# 응답 잘 옴
# 100페이지 items개수 30
# 응답 잘 옴
# 101페이지 items개수 30
# 응답 잘 옴
# 102페이지 items개수 30
# 응답 잘 옴
# 103페이지 items개수 30
# 응답 잘 옴
# 104페이지 items개수 30
# 응답 잘 옴
# 105페이지 items개수 30
# 응답 잘 옴
# 106페이지 items개수 30
# 응답 잘 옴
# 107페이지 items개수 30
# 응답 잘 옴
# 108페이지 items개수 30
# 응답 잘 옴
# 109페이지 items개수 30
# 응답 잘 옴
# 110페이지 items개수 30
# 응답 잘 옴
# 111페이지 items개수 30
# 응답 잘 옴
# 112페이지 items개수 30
# 응답 잘 옴
# 113페이지 items개수 30
# 응답 잘 옴
# 114페이지 items개수 30
# 응답 잘 옴
# 115페이지 items개수 30
# 응답 잘 옴
# 116페이지 items개수 30
# 응답 잘 옴
# 117페이지 items개수 30
# 응답 잘 옴
# 118페이지 items개수 30
# 응답 잘 옴
# 119페이지 items개수 30
# 응답 잘 옴
# 120페이지 items개수 30
# 응답 잘 옴
# 121페이지 items개수 30
# 응답 잘 옴
# 122페이지 items개수 30
# 응답 잘 옴
# 123페이지 items개수 30
# 응답 잘 옴
# 124페이지 items개수 30
# 응답 잘 옴
# 125페이지 items개수 30
# 응답 잘 옴
# 126페이지 items개수 30
# 응답 잘 옴
# 127페이지 items개수 30
# 응답 잘 옴
# 128페이지 items개수 30
# 응답 잘 옴
# 129페이지 items개수 30
# 응답 잘 옴
# 130페이지 items개수 30
# 응답 잘 옴
# 131페이지 items개수 30
# 응답 잘 옴
# 132페이지 items개수 30
# 응답 잘 옴
# 133페이지 items개수 30
# 응답 잘 옴
# 134페이지 items개수 30
# 응답 잘 옴
# 135페이지 items개수 30
# 응답 잘 옴
# 136페이지 items개수 30
# 응답 잘 옴
# 137페이지 items개수 13

# %%
review_data
# Out:
#              별점                                                 리뷰
# 0   None 4.26.화                                                  굿
# 0   None 4.30.토                                               좋아요
# 0   None 4.28.목                                               괜찮아요
# 0   None 4.25.월                                                좋아요
# 0   None 4.30.토                                                  굿
# ..          ...                                                ...
# 0    5 16.9.9.금  가는 날에 갑자기 해가 안 떠서 춥기 했지만 그래도 정말 재밌게 잘 놀았습니다 추우...
# 0    3 16.9.2.금  저렴한 가격에 이용해서 잘다녀왔구요 조금 스파밸리가 낡은 감이 있지만 재밌게 잘 놀...
# 0    3 16.9.2.금  시즌이 끝나갈때가서그런지 수질관리가 만족스럽지는 못했어요ㅠㅠ 유수풀도 차워진 날씨에...
# 0   5 16.8.18.목                현장결제보다 싸게 잘사용했습니다~더운데 시원하게 잘놀고 왔어요~
# 0   4 16.10.9.일                                         재밌고 즐거웠습니다
#
# [4093 rows x 2 columns]

# %%
review_data.to_csv('스파밸리_크롤링.csv', header= False, index =False)
